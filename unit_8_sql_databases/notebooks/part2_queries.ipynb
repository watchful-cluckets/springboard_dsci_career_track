# %%
# Import necessary module
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd

# %%
# Create engine: engine
engine = create_engine('sqlite:///../data/sqlite_db_pythonsqlite.db')
inspector = inspect(engine)

# Save the table names to a list: table_names
table_names = inspector.get_table_names()

# Print the table names to the shell
print(table_names)
# Out:
# ['Bookings', 'Facilities', 'Members']

# %%
# Q10
query = """
/* Q10: Produce a list of facilities with a total revenue less than 1000.
The output of facility name and total revenue, sorted by revenue. Remember
that there's a different cost for guests and members! */

SELECT NAME,
       revenue
FROM   (SELECT NAME,
               Sum(CASE
                     WHEN memid = 0 THEN guestcost * slots
                     ELSE membercost * slots
                   END) AS revenue
        FROM   Bookings
               INNER JOIN Facilities
                       ON Bookings.facid = Facilities.facid
        GROUP  BY NAME) AS inner_table
WHERE  revenue < 1000
ORDER  BY revenue;

"""
df = pd.read_sql_query(query, engine)
df
# Out:
#             NAME  revenue
# 0   Table Tennis      180
# 1  Snooker Table      240
# 2     Pool Table      270

# %%
# Q11
query = """
/* Q11: Produce a report of members and who recommended them in alphabetic surname,firstname order */

SELECT m.firstname || ' ' || m.surname       AS Recommended_By,
       rcmd.firstname || ' ' || rcmd.surname AS Member
FROM   members m
       INNER JOIN members rcmd
               ON rcmd.recommendedby = m.memid
WHERE  m.memid > 0
ORDER  BY m.surname,
          m.firstname,
          rcmd.surname,
          rcmd.surname

"""
df = pd.read_sql_query(query, engine)
df
# Out:
#        Recommended_By                   Member
# 0      Florence Bader         Ramnaresh Sarwin
# 1       Timothy Baker              Joan Coplin
# 2      Gerald Butters          Matthew Genting
# 3      Jemima Farrell            Timothy Baker
# 4      Jemima Farrell             David Pinker
# 5     Matthew Genting         Henrietta Rumney
# 6         David Jones            Douglas Jones
# 7     Janice Joplette               Nancy Dare
# 8     Janice Joplette              David Jones
# 9   Millicent Purview                John Hunt
# 10         Tim Rownam               Tim Boothe
# 11       Darren Smith           Gerald Butters
# 12       Darren Smith          Janice Joplette
# 13       Darren Smith           Anna Mackenzie
# 14       Darren Smith             Charles Owen
# 15       Darren Smith               Jack Smith
# 16        Tracy Smith            Erica Crumpet
# 17        Tracy Smith        Millicent Purview
# 18        Tracy Smith  Henry Worthington-Smyth
# 19    Ponder Stibbons           Florence Bader
# 20    Ponder Stibbons               Anne Baker
# 21       Burton Tracy          Ponder Stibbons

# %%
# Q12
query = """
/* Q12: Find the facilities with their usage by member, but not guests */
SELECT f.NAME,
       m.firstname || ' ' || m.surname AS Member,
       Count(f.NAME)                   AS bookings
FROM   members m
       INNER JOIN bookings bk
               ON bk.memid = m.memid
       INNER JOIN facilities f
               ON f.facid = bk.facid
WHERE  m.memid > 0
GROUP  BY f.NAME,
          m.firstname || ' ' || m.surname
ORDER  BY f.NAME,
          m.surname,
          m.firstname
"""

df = pd.read_sql_query(query, engine)
df
# Out:
#                 name           Member  bookings
# 0    Badminton Court   Florence Bader         9
# 1    Badminton Court       Anne Baker        10
# 2    Badminton Court    Timothy Baker         7
# 3    Badminton Court       Tim Boothe        12
# 4    Badminton Court   Gerald Butters        20
# ..               ...              ...       ...
# 197   Tennis Court 2     Darren Smith        19
# 198   Tennis Court 2       Jack Smith         1
# 199   Tennis Court 2      Tracy Smith         2
# 200   Tennis Court 2  Ponder Stibbons        31
# 201   Tennis Court 2     Burton Tracy         3
#
# [202 rows x 3 columns]

# %%
# Q13
query = """
/* Q13: Find the facilities usage by month, but not guests */

SELECT f.NAME,
       m.firstname || ' ' || m.surname AS Member,
       Count(f.NAME)                   AS bookings,
       Sum(CASE
             WHEN Month(starttime) = 1 THEN 1
             ELSE 0
           END)                            AS Jan,
       Sum(CASE
             WHEN Month(starttime) = 2 THEN 1
             ELSE 0
           END)                            AS Feb,
       Sum(CASE
             WHEN Month(starttime) = 3 THEN 1
             ELSE 0
           END)                            AS Mar,
       Sum(CASE
             WHEN Month(starttime) = 4 THEN 1
             ELSE 0
           END)                            AS Apr,
       Sum(CASE
             WHEN Month(starttime) = 5 THEN 1
             ELSE 0
           END)                            AS May,
       Sum(CASE
             WHEN Month(starttime) = 6 THEN 1
             ELSE 0
           END)                            AS Jun,
       Sum(CASE
             WHEN Month(starttime) = 7 THEN 1
             ELSE 0
           END)                            AS Jul,
       Sum(CASE
             WHEN Month(starttime) = 8 THEN 1
             ELSE 0
           END)                            AS Aug,
       Sum(CASE
             WHEN Month(starttime) = 9 THEN 1
             ELSE 0
           END)                            AS Sep,
       Sum(CASE
             WHEN Month(starttime) = 10 THEN 1
             ELSE 0
           END)                            AS Oct,
       Sum(CASE
             WHEN Month(starttime) = 11 THEN 1
             ELSE 0
           END)                            AS Nov,
       Sum(CASE
             WHEN Month(starttime) = 12 THEN 1
             ELSE 0
           END)                            AS Dec
FROM   members m
       INNER JOIN bookings bk
               ON bk.memid = m.memid
       INNER JOIN facilities f
               ON f.facid = bk.facid
WHERE  m.memid > 0
       AND Year(starttime) = 2012
GROUP  BY f.NAME,
          Concat(m.firstname, ' ', m.surname)
ORDER  BY f.NAME,
          m.surname,
          m.firstname
"""
df = pd.read_sql_query(query, engine)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# OperationalError: no such function: Month
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_1950942/751255924.py in <module>
#      65           m.firstname
#      66 """
# ---> 67 df = pd.read_sql_query(query, engine)
#      68 df
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1422     def execute(self, *args, **kwargs):
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#    1426     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3134         """
#    3135         connection = self.connect(close_with_result=True)
# -> 3136         return connection.execute(statement, *multiparams, **params)
#    3137
#    3138     @util.deprecated_20(
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1269             )
#    1270
# -> 1271             return self._exec_driver_sql(
#    1272                 statement,
#    1273                 multiparams,
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1573
#    1574         dialect = self.dialect
# -> 1575         ret = self._execute_context(
#    1576             dialect,
#    1577             dialect.execution_ctx_cls._init_statement,
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840
#    1841         except BaseException as e:
# -> 1842             self._handle_dbapi_exception(
#    1843                 e, statement, parameters, cursor, context
#    1844             )
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2021                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2022             elif should_wrap:
# -> 2023                 util.raise_(
#    2024                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2025                 )
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_execute(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such function: Month
# [SQL:
# SELECT f.NAME,
#        m.firstname || ' ' || m.surname AS Member,
#        Count(f.NAME)                   AS bookings,
#        Sum(CASE
#              WHEN Month(starttime) = 1 THEN 1
#              ELSE 0
#            END)                            AS Jan,
#        Sum(CASE
#              WHEN Month(starttime) = 2 THEN 1
#              ELSE 0
#            END)                            AS Feb,
#        Sum(CASE
#              WHEN Month(starttime) = 3 THEN 1
#              ELSE 0
#            END)                            AS Mar,
#        Sum(CASE
#              WHEN Month(starttime) = 4 THEN 1
#              ELSE 0
#            END)                            AS Apr,
#        Sum(CASE
#              WHEN Month(starttime) = 5 THEN 1
#              ELSE 0
#            END)                            AS May,
#        Sum(CASE
#              WHEN Month(starttime) = 6 THEN 1
#              ELSE 0
#            END)                            AS Jun,
#        Sum(CASE
#              WHEN Month(starttime) = 7 THEN 1
#              ELSE 0
#            END)                            AS Jul,
#        Sum(CASE
#              WHEN Month(starttime) = 8 THEN 1
#              ELSE 0
#            END)                            AS Aug,
#        Sum(CASE
#              WHEN Month(starttime) = 9 THEN 1
#              ELSE 0
#            END)                            AS Sep,
#        Sum(CASE
#              WHEN Month(starttime) = 10 THEN 1
#              ELSE 0
#            END)                            AS Oct,
#        Sum(CASE
#              WHEN Month(starttime) = 11 THEN 1
#              ELSE 0
#            END)                            AS Nov,
#        Sum(CASE
#              WHEN Month(starttime) = 12 THEN 1
#              ELSE 0
#            END)                            AS Dec
# FROM   members m
#        INNER JOIN bookings bk
#                ON bk.memid = m.memid
#        INNER JOIN facilities f
#                ON f.facid = bk.facid
# WHERE  m.memid > 0
#        AND Year(starttime) = 2012
# GROUP  BY f.NAME,
#           Concat(m.firstname, ' ', m.surname)
# ORDER  BY f.NAME,
#           m.surname,
#           m.firstname
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
